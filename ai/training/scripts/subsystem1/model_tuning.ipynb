# %%
import os
import torch
from ultralytics import YOLO

print(f"CUDA Available: {torch.cuda.is_available()}")
if torch.cuda.is_available():
    print(f"Using GPU Device: {torch.cuda.get_device_name(0)}")
else:
    print("WARNING: CUDA GPU not found. Training will run slowly on the CPU.")
    

torch.backends.cudnn.enabled = True
torch.backends.cudnn.benchmark = False
torch.backends.cudnn.deterministic = True
# Out:
# CUDA Available: True
# Using GPU Device: NVIDIA GeForce RTX 2050

# %%
model = YOLO("../runs/model_tuning_24062026/weights/best.pt")

model.train(
    data="../data/tin.yolov8.5/data.yaml",
    epochs=50,
    imgsz=640,
    device="0" if torch.cuda.is_available() else "cpu",
    batch=16,
    patience=20,
    project="../",
    name="model_tuning"
)
# Out:
# New https://pypi.org/project/ultralytics/8.4.77 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.4.54  Python-3.11.2 torch-2.7.1+cu118 CUDA:0 (NVIDIA GeForce RTX 2050, 4096MiB)
# ...

# %%
model = YOLO("../runs/model_tuning_01072026/weights/best.pt")

model.train(
    device="0" if torch.cuda.is_available() else "cpu",
    data="../data/tin.yolov8.closeup/data.yaml",
    epochs=35,
    lr0=0.0001,
    lrf=0.01,
    freeze=7,
    patience=10,
    imgsz=640,
    batch=8,
    project="../",
    name="model_tuning"
)
# Out:
# New https://pypi.org/project/ultralytics/8.4.82 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.4.54  Python-3.11.2 torch-2.7.1+cu118 CUDA:0 (NVIDIA GeForce RTX 2050, 4096MiB)
# ...

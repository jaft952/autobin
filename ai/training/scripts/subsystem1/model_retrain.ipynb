# %%
import torch
from ultralytics import YOLO

model = YOLO("../runs/baseline_run_20062026/weights/best.pt")

model.train(
    data="../data/tin.v4i.yolov8/data.yaml",
    epochs=50,
    imgsz=640,
    device="0" if torch.cuda.is_available() else "cpu",
    project="../",
    name="baseline_run_22062026"
)
# Out:
# New https://pypi.org/project/ultralytics/8.4.75 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.4.54  Python-3.11.2 torch-2.12.0+cpu CPU (12th Gen Intel Core i7-1255U)
# ...

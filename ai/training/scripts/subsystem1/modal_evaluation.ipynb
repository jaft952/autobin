# %%
from ultralytics import YOLO

model = YOLO("../runs/yolo11n-seg/weights/best.pt")
metrics = model.val(split="test", project="../", name="yolo11n-seg-test")

print(f"Final Test Accuracy (mAP50): {metrics.box.map50 * 100:.2f}%")
# Out:
# Ultralytics 8.4.54  Python-3.11.2 torch-2.7.1+cu118 CUDA:0 (NVIDIA GeForce RTX 2050, 4096MiB)
# YOLO11n-seg summary (fused): 114 layers, 2,834,763 parameters, 0 gradients, 9.6 GFLOPs
# val: Fast image access  (ping: 0.10.0 ms, read: 40.23.8 MB/s, size: 383.3 KB)
# val: Scanning C:\Users\harry\Desktop\autobin\data\augmented_tin\test\labels... 303 images, 25 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 303/303 284.8it/s 1.1s0.0s
# val: New cache created: C:\Users\harry\Desktop\autobin\data\augmented_tin\test\labels.cache
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 19/19 1.6it/s 12.0s0.3s
#                    all        303        372      0.986      0.966      0.993      0.949      0.992      0.962      0.992      0.912
# Speed: 3.3ms preprocess, 10.8ms inference, 0.0ms loss, 3.9ms postprocess per image
# Results saved to C:\Users\harry\Desktop\autobin\runs\yolo11n-seg-test
# Final Test Accuracy (mAP50): 99.34%

# %%
import shutil
import os
from datetime import datetime

source_path = "../runs/model_tuning/weights/best.pt"
dest_dir = "../src/models"
# today = datetime.now().strftime("%d%m%Y")
today = "01072026"
dest_path = os.path.join(dest_dir, f"inference_{today}.pt")

os.makedirs(dest_dir, exist_ok=True)

shutil.copy(source_path, dest_path)
print(f"Successfully deployed champion model to: {dest_path}")
# Out:
# Successfully deployed champion model to: ../src/models\inference_01072026.pt

# %%
from datetime import datetime

model_dir = "../runs/model_tuning"
evaluation_dir = "../runs/model_evaluation"

if os.path.exists(model_dir):
    # today = datetime.now().strftime("%d%m%Y")
    today = "01072026"
    new_model_dir = f"../runs/model_tuning_{today}"
    os.rename(model_dir, new_model_dir)
    print(f"Renamed previous model folder to: {new_model_dir}")

if os.path.exists(evaluation_dir):
    # today = datetime.now().strftime("%d%m%Y")
    today = "01072026"
    new_evaluation_dir = f"../runs/model_evaluation_{today}"
    os.rename(evaluation_dir, new_evaluation_dir)
    print(f"Renamed previous evaluation folder to: {new_evaluation_dir}")
# Out:
# Renamed previous model folder to: ../runs/model_tuning_01072026
# Renamed previous evaluation folder to: ../runs/model_evaluation_01072026
